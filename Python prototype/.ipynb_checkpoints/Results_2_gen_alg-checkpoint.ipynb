# %%
import numpy as np
from PIL import Image, ImageOps
import math
import random
import sys, getopt
from scipy.fft import fft2, fftfreq, fftshift, ifft2
from scipy import fftpack, ndimage
from matplotlib import pyplot as plt
import cmath
from scipy.signal import convolve2d
from matplotlib.pyplot import imread
import os
import time

def M(x, y):
    if(x**2 + y**2 < (math.pi/2)**2):
        return 1
    else:
        return 0
    
def p_s(x, y, delta_z):
    return 0.375 * abs(delta_z) * math.pi * (x**2 + y**2)

def p(x, y):
    return 0.5 * math.pi * (x**2 + y**2)

def h_orig(delta_z, sh_orig):  # создает матрицу для фильтра нужной нам размерности (h)
                               # от сигма зависит степень размытия. чем больше сигма тем больше размытие
    
    matr = np.zeros(shape = (sh_orig, sh_orig), dtype = np.complex128) # матрица из 0 (по размеру изборжания подаваемого)
                                          
    #|F(M(x,y)∙exp{i∙p_s (x,y,∆z_nm )+i∙p(x,y)})|
     
    for i in range(matr.shape[0]):
        for j in range(matr.shape[1]):
            x = math.pi/sh_orig * (i - sh_orig/2)
            y = math.pi/sh_orig * (j - sh_orig/2)
            matr[i, j] = M(x,y) * cmath.exp(1j * p_s(x, y, delta_z) + 1j * p(x, y))
    return abs(fftshift(fft2(matr)))**2


def read_fft_pics_rash(number_of_pics, sh_orig, part_of_path):
    pics = [0] * number_of_pics
#     path = (os.path.abspath(os.curdir))+'/'+str(sh_orig)+'x'+str(sh_orig)+'/'
    path = os.path.abspath(os.curdir) + part_of_path
    dir_pics = os.listdir(path = path)
    dir_pics.sort()
    
    for i in range(number_of_pics):
        im = Image.open(path + dir_pics[i],'r')

        data = np.array(im)                                                #представляем как массив
        data_im_fl = data[:,:].astype(np.float)
        
        im_f_n = np.zeros(shape = (sh_orig*2,sh_orig*2), dtype = float)
        im_f_n[0:int(sh_orig), 0:int(sh_orig)] = data_im_fl                #расширяем
        
        pics[i] += fft2(im_f_n)
    return pics

def h_rash(amount_of_pics, sh_orig, part__of_delta_z):
    mas_of_h = [0] * amount_of_pics
    
    for i in range (0, amount_of_pics):
        h_f_n = np.zeros(shape = (sh_orig*2,sh_orig*2), dtype = np.complex128)
        h_f_n[0:int(sh_orig), 0:int(sh_orig)] = h_orig(delta_z = part__of_delta_z * i, sh_orig = sh_orig)
        h_sum = np.sum(h_f_n)
        for k in range(h_f_n.shape[0]): #нормировка
            for f in range(h_f_n.shape[1]):
                h_f_n[k][f] /= h_sum
        mas_of_h[i] += (fft2(h_f_n))
    return mas_of_h

# %%
def recovery(amount_of_pics, mas_of_h, mu, iters):

    E = np.mat(np.eye(3), dtype = np.complex128)

    b = [0] * amount_of_pics

    res = np.zeros(shape = (amount_of_pics, sh_orig*2, sh_orig*2), dtype = np.complex128) 

    for u in range(sh_orig*2):
        for v in range(sh_orig*2):
            A = np.mat([ [mas_of_h[0][u][v], mas_of_h[1][u][v], mas_of_h[2][u][v]], 
             [mas_of_h[1][u][v], mas_of_h[0][u][v], mas_of_h[1][u][v]],
             [mas_of_h[2][u][v], mas_of_h[1][u][v], mas_of_h[0][u][v]] ], dtype = np.complex128)

            for i in range(amount_of_pics):
                b[i] = pics[i][u][v]
            O = [0] * amount_of_pics
            factor = np.linalg.inv(E + mu*A.H.dot(A))
            for k in range(iters):
                lala = (factor).dot(O).transpose()
                O_new = ( lala + factor.dot( (A.H.dot(b)).transpose() ) ).getA1()
    #             if (np.linalg.norm(O_new - O) < 0.1):
    #                 break
                O = O_new

    #         print('O')
    #         print(O)

            for i in range(amount_of_pics):
    #             print(type(O.getA1()[i]))
    #             print(type(res))
                res[i][u][v] = O[i]
#         print(u)

#     print(O[0])
    res1 = [0] * amount_of_pics
    for i in range(amount_of_pics):
        res1[i] = fftshift(ifft2(res[i]))
    return res1

# %%
# %matplotlib inline

sh_orig = 256
amount_of_pics = 3
part__of_delta_z = math.pi

part_of_path = '/rev/'+str(sh_orig)+'x'+str(sh_orig)+'/'+'p05Ih1/'

pics =  read_fft_pics_rash(amount_of_pics, sh_orig, part_of_path)
mas_of_h = h_rash(amount_of_pics, sh_orig, part__of_delta_z)

# final = [0] * len(pics)
# for m in range(amount_of_pics):
#     for n in range(amount_of_pics):
#         final[m] += abs(ifft2(pics[n] * mas_of_h[abs(n-m)]))

# %%
######################
# p = 0.5 * math.pi
# h = pi
# mu = 1
# K = 15
######################
# Out:
# <ipython-input-68-95e1f171abbb>:30: ComplexWarning: Casting complex values to real discards the imaginary part
#   axarr1[0].imshow(res1[0].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")
# <ipython-input-68-95e1f171abbb>:31: ComplexWarning: Casting complex values to real discards the imaginary part
#   axarr1[1].imshow(res1[1].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")
# <ipython-input-68-95e1f171abbb>:32: ComplexWarning: Casting complex values to real discards the imaginary part
#   axarr1[2].imshow(res1[2].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")

# %%
######################
# p = 0.5 * math.pi
# h = pi
# mu = 1
# K = 30
######################
# Out:
# <ipython-input-69-b0c84559c1ce>:37: ComplexWarning: Casting complex values to real discards the imaginary part
#   axarr1[0].imshow(res1[0].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")
# <ipython-input-69-b0c84559c1ce>:38: ComplexWarning: Casting complex values to real discards the imaginary part
#   axarr1[1].imshow(res1[1].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")
# <ipython-input-69-b0c84559c1ce>:39: ComplexWarning: Casting complex values to real discards the imaginary part
#   axarr1[2].imshow(res1[2].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")

# %%
######################
# p = 0.5 * math.pi
# h = pi
# mu = 10
# K = 5
######################
# Out:
# <ipython-input-71-925574d6f33d>:37: ComplexWarning: Casting complex values to real discards the imaginary part
#   axarr1[0].imshow(res1[0].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")
# <ipython-input-71-925574d6f33d>:38: ComplexWarning: Casting complex values to real discards the imaginary part
#   axarr1[1].imshow(res1[1].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")
# <ipython-input-71-925574d6f33d>:39: ComplexWarning: Casting complex values to real discards the imaginary part
#   axarr1[2].imshow(res1[2].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")

# %%
######################
# p = 0.5 * math.pi
# h = pi
# mu = 10
# K = 15
######################
# Out:
# <ipython-input-72-c8f8d4d777d8>:37: ComplexWarning: Casting complex values to real discards the imaginary part
#   axarr1[0].imshow(res1[0].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")
# <ipython-input-72-c8f8d4d777d8>:38: ComplexWarning: Casting complex values to real discards the imaginary part
#   axarr1[1].imshow(res1[1].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")
# <ipython-input-72-c8f8d4d777d8>:39: ComplexWarning: Casting complex values to real discards the imaginary part
#   axarr1[2].imshow(res1[2].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")

# %%
######################
# p = 0.5 * math.pi
# h = pi
# mu = 100
# K = 5
######################
# Out:
# <ipython-input-76-621e5f0d1570>:37: ComplexWarning: Casting complex values to real discards the imaginary part
#   axarr1[0].imshow(res1[0].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")
# <ipython-input-76-621e5f0d1570>:38: ComplexWarning: Casting complex values to real discards the imaginary part
#   axarr1[1].imshow(res1[1].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")
# <ipython-input-76-621e5f0d1570>:39: ComplexWarning: Casting complex values to real discards the imaginary part
#   axarr1[2].imshow(res1[2].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")

# %%
######################
# p = 0.5 * math.pi
# h = pi
# mu = 500
# K = 5
######################

res1 = [0] * amount_of_pics

mu = 500
iters = 5
res1 = recovery(amount_of_pics, mas_of_h, mu, iters)

data_im_fl = [0] *3

im = Image.open(os.path.abspath(os.curdir) + part_of_path + 'image0'+str(1)+'.png','r')
data = np.array(im)                                                #представляем как массив
data_im_fl[0] = data[:,:].astype(np.float)

im = Image.open(os.path.abspath(os.curdir) + part_of_path + 'image0'+str(2)+'.png','r')
data = np.array(im)                                                #представляем как массив
data_im_fl[1] = data[:,:].astype(np.float)

im = Image.open(os.path.abspath(os.curdir) + part_of_path + 'image0'+str(3)+'.png','r')
data = np.array(im)                                                #представляем как массив
data_im_fl[2] = data[:,:].astype(np.float)
    
plt.figure()
plt.rcParams["figure.figsize"] = [50.00, 30]

#subplot(r,c) provide the no. of rows and columns
f, axarr = plt.subplots(1,3) 
axarr[0].imshow(data_im_fl[0].astype(float)[:,:], cmap = "gist_gray")
axarr[1].imshow(data_im_fl[1].astype(float)[:,:], cmap = "gist_gray")
axarr[2].imshow(data_im_fl[2].astype(float)[:,:], cmap = "gist_gray") 
f, axarr1 = plt.subplots(1,3)
axarr1[0].imshow(res1[0].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")
axarr1[1].imshow(res1[1].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")
axarr1[2].imshow(res1[2].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")
# Out:
# <ipython-input-77-d025d15e50cd>:37: ComplexWarning: Casting complex values to real discards the imaginary part
#   axarr1[0].imshow(res1[0].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")
# <ipython-input-77-d025d15e50cd>:38: ComplexWarning: Casting complex values to real discards the imaginary part
#   axarr1[1].imshow(res1[1].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")
# <ipython-input-77-d025d15e50cd>:39: ComplexWarning: Casting complex values to real discards the imaginary part
#   axarr1[2].imshow(res1[2].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")

# %%
######################
# p = 0.5 * math.pi
# h = pi
# mu = 1000
# K = 5
######################
# Out:
# <ipython-input-79-07ea945b1ee1>:36: ComplexWarning: Casting complex values to real discards the imaginary part
#   axarr1[0].imshow(res1[0].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")
# <ipython-input-79-07ea945b1ee1>:37: ComplexWarning: Casting complex values to real discards the imaginary part
#   axarr1[1].imshow(res1[1].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")
# <ipython-input-79-07ea945b1ee1>:38: ComplexWarning: Casting complex values to real discards the imaginary part
#   axarr1[2].imshow(res1[2].astype(float)[int(sh_orig/2):int(sh_orig+sh_orig/2),int(sh_orig/2):int(sh_orig+sh_orig/2)], cmap = "gist_gray")
